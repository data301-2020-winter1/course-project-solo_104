# %%
from Scripts import Project_Functions
df = Project_Functions.load_and_process("/Users/marcusdecloux/Documents/DATA301/course-project-solo_104/Data/Raw/Games.csv")
df
# Out:
#                     Team  CF  CA    CF%  SF  SA    SF%  GF  GA     GF%  ...  \
# 0     Chicago Blackhawks  69  51  57.50  42  29  59.15   6   4   60.00  ...
# 1        Edmonton Oilers  51  69  42.50  29  42  40.85   4   6   40.00  ...
# 2     Montreal Canadiens  64  96  40.00  35  41  46.05   3   2   60.00  ...
# 3    Pittsburgh Penguins  96  64  60.00  41  35  53.95   2   3   40.00  ...
# 4         Calgary Flames  50  45  52.63  33  18  64.71   4   1   80.00  ...
# ..                   ...  ..  ..    ...  ..  ..    ...  ..  ..     ...  ...
# 253  Tampa Bay Lightning  68  58  53.97  35  30  53.85   5   4   55.56  ...
# 254         Dallas Stars  68  92  42.50  33  41  44.59   3   2   60.00  ...
# 255  Tampa Bay Lightning  92  68  57.50  41  33  55.41   2   3   40.00  ...
# 256         Dallas Stars  57  55  50.89  22  29  43.14   0   2    0.00  ...
# 257  Tampa Bay Lightning  55  57  49.11  29  22  56.86   2   0  100.00  ...
#
# ...

# %% [markdown]
# **INTRODUCTION**
# Natural Stat Tricks "Games.csv" is a collection of analytical and statistical measures taken from the 2020 NHL Stanley Cup Playoffs. Each row represents one of the teams involved in each game and their corresponding values for each metric. The conclusion of the playoffs saw the Tampa Bay Lightning claim their second franchise Stanley Cup. In light of this, do the so-called "fancy stats" indicate that Tampa Bay was worthy of winning the cup? To investigate this, consider various metrics which indicate how *lucky* or *unlucky* a team was, such as Shooting plus Save percentage (PDO), Corsi For (CF%), and Shots For percentage (SF%) among many others.

# %% [markdown]
# **RESEARCH QUESTION 1: Do the Advanced Stats Indicate that Tampa Bay was Worthy of Winning?**

# %% [markdown]
# First, let us examine a plot that indicates how good each team in the playoffs was at creating offensive opportunities.

# %%
Project_Functions.SFGFdata(df)
# Out:
# /Users/marcusdecloux/Documents/DATA301/course-project-solo_104/Analysis/Scripts/Project_Functions.py:141: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(
#                      Team        SF%        GF%
# 0    Vegas Golden Knights  59.584500  55.166000
# 1      Colorado Avalanche  57.094000  62.632000
# 2     Nashville Predators  56.222500  43.097500
# 3     Toronto Maple Leafs  54.744000  40.000000
# 4     Tampa Bay Lightning  54.045600  57.406800
# 5     Pittsburgh Penguins  53.492500  39.465000
# 6          St Louis Blues  53.305000  43.452500
# 7         Edmonton Oilers  52.967500  47.382500
# 8           Boston Bruins  52.407692  43.818462
# 9      Montreal Canadiens  51.468000  47.797000
# 10         Minnesota Wild  51.160000  46.825000
# 11     New York Islanders  50.705455  59.201364
# 12         Calgary Flames  49.979000  60.721000
# 13    Washington Capitals  47.958750  36.220000
# ...

# %% [markdown]
# GF% (Goals For Percent, found by Goals For over Total Goals -> GF/G * 100%) and SF% (Shots For Percent, found by Shots For over Total Shots -> SF/S * 100%) are indicators of which team controls the offensive pace of the game. Teams that do both well provide a fair goals to shots ratio, meaning they dont suffer from poor shooting. Tampa Bay is only outranked in **both** measures by the Vegas Golden Knights and the Colorado Avalanche, both Western Conference Teams that Tampa Bay did not need to play to win the playoffs this year. This scatterplot indicates Tampa Bay played a solid offensive game in the 2020 playoffs.

# %% [markdown]
# Moreover, next we should consider a defensive metric.

# %%
Project_Functions.SVperdata(df)
# Out:
#                      Team        SV%
# 0   Columbus Blue Jackets  93.241000
# 1      Montreal Canadiens  92.961000
# 2     Carolina Hurricanes  92.822500
# 3     Toronto Maple Leafs  92.732000
# 4       Vancouver Canucks  92.557059
# 5      New York Islanders  92.347273
# 6     Philadelphia Flyers  92.021875
# 7     Tampa Bay Lightning  91.852000
# 8     Pittsburgh Penguins  91.435000
# 9          Calgary Flames  91.213000
# 10   Vegas Golden Knights  90.831000
# 11           Dallas Stars  90.643077
# 12     Colorado Avalanche  90.486000
# 13     Chicago Blackhawks  90.212222
# 14         Minnesota Wild  89.810000
# 15       Florida Panthers  89.712500
# 16          Boston Bruins  89.692308
# 17        Arizona Coyotes  89.506667
# 18       New York Rangers  89.076667
# 19    Nashville Predators  88.862500
# 20    Washington Capitals  87.756250
# 21          Winnipeg Jets  87.675000
# 22        Edmonton Oilers  86.957500
# 23         St Louis Blues  86.707500

# %% [markdown]
# SV% is a measure used to describe how good a goalie is, on average. It is computed by dividing the total number of saves by the total number of shots against (SV/SA * 100%). Per Hockey Reference, the league average SV% in 2019-2020 was 91.0% [link](https://www.hockey-reference.com/leagues/stats.html). Thus teams that recorded a higher SV% had good goaltending, and by extension good defense. Tampa Bay ranks 8th among all playoff teams, and were significantly higher than league average. It is not a stretch to say that Tampa Bay provided excellent goaltending and defense in the 2020 Playoffs.

# %% [markdown]
# One of the most common metrics is CF%. CF% is a measure of Shot Attempts (i.e. shots directly towards the goal, regardless of wether they are blocked, miss, are saved, or go in) For to total shot attempts. CF% is used to indicate who controls the game, with the logic that the team controlling the game wins everytime. In practice, this is very rarely true, mostly due to the parity in the league.

# %%
Project_Functions.CFdata(df)
# Out:
#                      Team        CF%
# 0    Vegas Golden Knights  58.672000
# 1      Colorado Avalanche  56.892667
# 2     Nashville Predators  54.475000
# 3     Pittsburgh Penguins  53.955000
# 4     Tampa Bay Lightning  53.712000
# 5     Toronto Maple Leafs  52.898000
# 6           Boston Bruins  52.293077
# 7          Minnesota Wild  51.822500
# 8          St Louis Blues  51.651250
# 9         Edmonton Oilers  51.452500
# 10    Washington Capitals  51.301250
# 11     Montreal Canadiens  51.023000
# 12          Winnipeg Jets  50.195000
# 13       Florida Panthers  49.540000
# 14    Carolina Hurricanes  48.846250
# 15         Calgary Flames  48.066000
# 16     New York Islanders  47.979091
# 17    Philadelphia Flyers  47.771250
# 18           Dallas Stars  46.367692
# 19       New York Rangers  46.163333
# 20  Columbus Blue Jackets  45.459000
# 21     Chicago Blackhawks  45.077778
# 22        Arizona Coyotes  42.727778
# 23      Vancouver Canucks  42.721176

# %% [markdown]
# Tampa Bay once again ranks fairly high on this list. As a basic rule of thumb, having a CF% higher than 50 would be indicative of a team being a better controller of the game. Each of the teams that managed a better CF% - Vegas, Colorado, Nashville, and Pittsburgh - were all elimanated before Tampa Bay had to play them. Thus the Tampa Bay Lightning were an excellent team at controlling the whole game.

# %% [markdown]
# Lastly, consider how *lucky* each team was.

# %%
Project_Functions.PDOdata(df)
# Out:
#                      Team       PDO
# 0       Vancouver Canucks  1.033353
# 1     Carolina Hurricanes  1.026125
# 2      New York Islanders  1.025455
# 3      Colorado Avalanche  1.020467
# 4          Calgary Flames  1.017800
# 5     Tampa Bay Lightning  1.014960
# 6   Columbus Blue Jackets  1.010500
# 7      Chicago Blackhawks  1.009222
# 8     Philadelphia Flyers  1.008063
# 9            Dallas Stars  1.007308
# 10     Montreal Canadiens  1.004200
# 11   Vegas Golden Knights  0.990200
# 12        Edmonton Oilers  0.984750
# 13        Arizona Coyotes  0.982556
# 14         Minnesota Wild  0.978500
# 15    Toronto Maple Leafs  0.974600
# 16    Pittsburgh Penguins  0.969000
# 17       Florida Panthers  0.967750
# 18          Boston Bruins  0.966077
# 19    Nashville Predators  0.962500
# 20         St Louis Blues  0.953000
# 21    Washington Capitals  0.943875
# 22       New York Rangers  0.939000
# 23          Winnipeg Jets  0.933750

# %% [markdown]
# In general, PDO measures how lucky a team is by combining the shooting and save percentages of a team. PDO values higher than 1.02 would imply that the team survived via unntaurally high shooting or save percentages (or both). Conversely, a PDO less than 0.98 is indicative of poor luck. The results of the 2020 Playoff PDO show that Tampa Bay was good, but not lucky, as their PDO scored at 1.014 which is high but not too high.

# %% [markdown]
# **ANALYSIS**
# By each of the above metrics, Tampa Bay was certianly one of the best teams in the playoffs. Arguably, the Lightning were the best Eastern Conference team by the above metrics. By the numbers, Tampa Bay provided a forecful offensive game, were beneficiaries of an above average goaltending and defensive efforts, which in general lead to an ability to exert control over the opposition throughout the game. Tampa Bay cannot be viewed as lucky, analytically. By these numbers, Tampa Bay was certianly worthy of winning the cup
# The opposition to *fancy stats* is generally called the "Eye-Test". This does not include the use of numbers, but takes the general public thought for each team as face value. Tampa Bay was certiantly a good team by the Eye-Test, arguably employing the best Goaltender, Defenceman and Winger in the league. Tampa Bay is known as a phenomenal team under any method of looking at the value each team provides.
# In conclusion, analytically, the Tampa Bay Lightning were a worthy winner of the 2020 Stanley Cup Playoffs

# %% [markdown]
# **RESEARCH QUESTION 2: Do Fancy Stats Tell the Whole Story?**

# %% [markdown]
# Due to the intense parity featured in the NHL, the worst team in the league is capable of beating the best on any given night. Sometimes the worse analytical team is the one that wins. This did occur in the Western Conference Playoffs in 2020, when the Dallas Stars advanced to the finals over the VEgas Golden Knights. What explains this phenomenon?

# %% [markdown]
# First consider again teams PDO

# %%
Project_Functions.PDOdata(df)
# Out:
#                      Team       PDO
# 0       Vancouver Canucks  1.033353
# 1     Carolina Hurricanes  1.026125
# 2      New York Islanders  1.025455
# 3      Colorado Avalanche  1.020467
# 4          Calgary Flames  1.017800
# 5     Tampa Bay Lightning  1.014960
# 6   Columbus Blue Jackets  1.010500
# 7      Chicago Blackhawks  1.009222
# 8     Philadelphia Flyers  1.008063
# 9            Dallas Stars  1.007308
# 10     Montreal Canadiens  1.004200
# 11   Vegas Golden Knights  0.990200
# 12        Edmonton Oilers  0.984750
# 13        Arizona Coyotes  0.982556
# 14         Minnesota Wild  0.978500
# 15    Toronto Maple Leafs  0.974600
# 16    Pittsburgh Penguins  0.969000
# 17       Florida Panthers  0.967750
# 18          Boston Bruins  0.966077
# 19    Nashville Predators  0.962500
# 20         St Louis Blues  0.953000
# 21    Washington Capitals  0.943875
# 22       New York Rangers  0.939000
# 23          Winnipeg Jets  0.933750

# %% [markdown]
# In a similar fashion to Tampa Bay, the Stars cannot be considered a lucky team for the duration of the 2020 Playoffs due to their middle-of-the-pack PDO 0f 1.007. The Stars were not necessarily boosted by above average shooting or save percentages.

# %% [markdown]
# If we consider CF% we start to see a different trend begin.

# %%
Project_Functions.CFdata(df)
# Out:
#                      Team        CF%
# 0    Vegas Golden Knights  58.672000
# 1      Colorado Avalanche  56.892667
# 2     Nashville Predators  54.475000
# 3     Pittsburgh Penguins  53.955000
# 4     Tampa Bay Lightning  53.712000
# 5     Toronto Maple Leafs  52.898000
# 6           Boston Bruins  52.293077
# 7          Minnesota Wild  51.822500
# 8          St Louis Blues  51.651250
# 9         Edmonton Oilers  51.452500
# 10    Washington Capitals  51.301250
# 11     Montreal Canadiens  51.023000
# 12          Winnipeg Jets  50.195000
# 13       Florida Panthers  49.540000
# 14    Carolina Hurricanes  48.846250
# 15         Calgary Flames  48.066000
# 16     New York Islanders  47.979091
# 17    Philadelphia Flyers  47.771250
# 18           Dallas Stars  46.367692
# 19       New York Rangers  46.163333
# 20  Columbus Blue Jackets  45.459000
# 21     Chicago Blackhawks  45.077778
# 22        Arizona Coyotes  42.727778
# 23      Vancouver Canucks  42.721176

# %% [markdown]
# By all accounts, Vegas was more deserving of a trip to the finals than Dallas. Dallas was a poor possession team during the playoffs with a CF% well below 50%, meaning they were, on average, dominated throughout the playoffs. And yet Dallas bucked the trend, deafeating the top two possession teams in Vegas and Colorado in subsequent rounds.

# %%
Project_Functions.SVperdata(df)
# Out:
#                      Team        SV%
# 0   Columbus Blue Jackets  93.241000
# 1      Montreal Canadiens  92.961000
# 2     Carolina Hurricanes  92.822500
# 3     Toronto Maple Leafs  92.732000
# 4       Vancouver Canucks  92.557059
# 5      New York Islanders  92.347273
# 6     Philadelphia Flyers  92.021875
# 7     Tampa Bay Lightning  91.852000
# 8     Pittsburgh Penguins  91.435000
# 9          Calgary Flames  91.213000
# 10   Vegas Golden Knights  90.831000
# 11           Dallas Stars  90.643077
# 12     Colorado Avalanche  90.486000
# 13     Chicago Blackhawks  90.212222
# 14         Minnesota Wild  89.810000
# 15       Florida Panthers  89.712500
# 16          Boston Bruins  89.692308
# 17        Arizona Coyotes  89.506667
# 18       New York Rangers  89.076667
# 19    Nashville Predators  88.862500
# 20    Washington Capitals  87.756250
# 21          Winnipeg Jets  87.675000
# 22        Edmonton Oilers  86.957500
# 23         St Louis Blues  86.707500

# %% [markdown]
# The Stars ranked slightly below the league average SV%, meaning they did not win by playing a red hot goalie throughout the playoffs, like some other teams managed to do. It is worth noting that SV% will regress to the average in the long term, such as over a cup run. Dallas did not benefit from a particularly great defensive effort.

# %% [markdown]
# **ANALYSIS**
# So how did Dallas advance all the way through the playoffs if the numbers indicate that they were not a particularly good team, and nor could they be considered lucky? The answer lies in the fact that real life is always significantly more complicated than models that can be applied to the observations of the events. Dallas appeared to have extremely opportunistic offense and won by playing suffocating hockey all over the ice - which usually results in poor metrics, but also can prove to be effective to win hockey games.
# The Eye-Test would ratify this claim. The Stars are built to withstand heavy offense and be able to grind out wins over teams that are arguably more talented. The Stars feature many players that fit this mould. Ultimately, this strategy lead to an almost perfect Stanley Cup Playoffs, before they ran into a team that was just as well proportioned for playoff hockey. Additionally, many other factors may have contributed to the Stars victories over Vegas and Colorado, including a lack of confidence, injuries and poor powerplays.

# %% [markdown]
# **CONCLUSION**
# Following the analysis of the stats gathered on the 2020 Stanley Cup Playoffs, it is clear that while Tampa Bay may not have been the best analytical team, but they were better than any of the teams they defeated -Columbus Blue Jackets, Boston Bruins, New York Islanders and Dallas Stars- by nearly every statistic. Therefore Tampa Bay was clearly deserving of their second franchsise Stanley Cup.
# In the West, Dallas was the opposite case. They were a team that was continually dominated throughout the playoffs, yet managed to reel off succesive wins over some of the best teams in the playoffs, and came within a goal of playing in a game 7 winner take-all final. Therefore, the *fancy stats* clearly do not tell the whole story, and the Eye-Test is still a worthwhile component to predicting the success of a given team.
